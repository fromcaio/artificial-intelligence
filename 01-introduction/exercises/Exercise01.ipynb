# %% [markdown]
# # Artificial Intelligence — Module 01
# ## Exercise 01 — Introduction Reflection
#
# Notebook by: **Caio Reis** (Repository Author)

# %% [markdown]
# ### Instructions
#
#
# Reflect individually on the prompts below and capture your answers in the Markdown cell provided.
#
# Focus on your own experiences and insights.

# %% [markdown]
# ### Discussion Points
#
# 1.  **AI Applications:** Which other AI applications do you know or use (e.g., Netflix, Waze, Siri)?
#
# 2.  **Myths and Facts:** What common myths or truths do you hear about AI (e.g., "AI will steal all jobs," "AI is conscious," "AI only works for big companies")?
#
# 3.  **Current Use:** Which AI-powered systems do you personally rely on each day (virtual assistants, games, email spam filters, social media feeds, etc.)?
#
# 4.  **The Big Question:** Will AI replace humans? Why or why not? Clarify what "replace" means, consider whether it applies to all or some tasks, and whether new human roles might appear.

# %% [markdown]
# ---
#
# ### Response Template
#
# **Your Name:**
# (Write your name here)
#
# **1. Other AI Applications:**
#
# (Write your answer here...)
#
# **2. Myths and Facts:**
#
# (Write your answer here...)
#
# **3. Our Current AI Use:**
#
# (Write your answer here...)
#
# **4. Will AI Replace Humans?**
#
# (State your position here...)
#
# ---
